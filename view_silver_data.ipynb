# %%
# !pip install duckdb
# Out:
# Requirement already satisfied: duckdb in ./.venv/lib/python3.13/site-packages (1.4.1)

# %%
import os
import duckdb

# That's it! No server, no container needed
con = duckdb.connect()

# Configure to connect to your MinIO
con.execute(f"""
    SET s3_endpoint='localhost:9000';
    SET s3_access_key_id='{os.getenv('MINIO_ROOT_USER')}';
    SET s3_secret_access_key='{os.getenv('MINIO_ROOT_PASSWORD')}';
    SET s3_use_ssl=false;
    SET s3_url_style='path';
""")

# Queries here!
df = con.execute("""
                 
    SELECT * FROM read_parquet('s3://silver/taxi_data.parquet/*.parquet') 
    LIMIT 10;
""").df()

print(f"Number of rows: {len(df)}")
df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPException                             Traceback (most recent call last)
# Cell In[16], line 17
#       8 con.execute(f"""
#       9     SET s3_endpoint='localhost:9000';
#      10     SET s3_access_key_id='{os.getenv('MINIO_ROOT_USER')}';
#    (...)     13     SET s3_url_style='path';
#      14 """)
#      16 # Queries here!
# ---> 17 df = con.execute("""
#      18
#      19     SELECT * FROM read_parquet('s3://silver/taxi_data.parquet/*.parquet')
#      20     LIMIT 10;
#      21 """).df()
#      23 print(f"Number of rows: {len(df)}")
#      24 df.head()
#
# HTTPException: HTTP Error: HTTP GET error reading 's3://silver/taxi_data.parquet/silver/?encoding-type=url&list-type=2&prefix=taxi_data.parquet%2F' in region '' (HTTP 403 Forbidden)
#
# Authentication Failure - this is usually caused by invalid or missing credentials.
# * Credentials are provided, but they did not work.
# * See https://duckdb.org/docs/stable/extensions/httpfs/s3api.html
#
# LINE 3:     SELECT * FROM read_parquet('s3://silver/taxi_data.parquet/*.parquet')
#                           ^
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#     ~~~~~~~~^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 339, in dispatch_control
#     await self.process_control(msg)
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 345, in process_control
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/bogdan/code/etl-pipeline/.venv/lib/python3.13/site-packages/jupyter_client/session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
